# %%
import os
import pandas as pd
import numpy as np

DIR = os.getcwd()
print(DIR)

df = pd.read_csv(DIR + "/2008contributions.csv",
                    parse_dates = ["contribution_receipt_date"]) 

df.head()
# Out:
# /Users/lukedobrovic/Data/CampaignContributions
#   committee_id                 committee_name  report_year report_type  \
# 0    C00193433                   EMILY'S LIST         2008         M10
# 1    C00193433                   EMILY'S LIST         2008         M10
# 2    C00193433                   EMILY'S LIST         2008          M3
# 3    C00088484  FRIENDS OF SENATOR CARL LEVIN         2007          Q1
# 4    C00431445              OBAMA FOR AMERICA         2008         M10
#
#    image_number line_number transaction_id  file_number  committee_name.1  \
# 0   29933614894        11AI        2458018       415592               NaN
# 1   29933611419        11AI        2467065       415592               NaN
# 2   28990613101        11AI        2349804       327583               NaN
# 3   27020120591        11AI            NaN       286627               NaN
# 4   11972575354         17A        7087420       753817               NaN
#
#   entity_type  ... filing_form              link_id is_individual  \
# 0         IND  ...         F3X  4042920091114302988             t
# 1         IND  ...         F3X  4042920091114302988             t
# 2         IND  ...         F3X  4031920081086070319             t
# 3         IND  ...          F3  1041720120009728668             t
# 4         IND  ...         F3P  4112820111146120195             t
#
#                              memo_text two_year_transaction_period  \
# 0                                 MEMO                        2008
# 1                                  NaN                        2008
# 2                                 MEMO                        2008
# 3  * EARMARKED CONTRIBUTION: SEE BELOW                        2008
# 4                                  NaN                        2008
#
#   schedule_type increased_limit               sub_id  \
# 0            SA             NaN  4042920091114370912
# 1            SA             NaN  4042920091114360446
# 2            SA             NaN  4040920081087233475
# 3            SA             NaN  1041720120009729862
# 4            SA             NaN  4113020111146674515
#
#                                              pdf_url  \
# 0  http://docquery.fec.gov/cgi-bin/fecimg/?299336...
# 1  http://docquery.fec.gov/cgi-bin/fecimg/?299336...
# 2  http://docquery.fec.gov/cgi-bin/fecimg/?289906...
# 3  http://docquery.fec.gov/cgi-bin/fecimg/?270201...
# 4  http://docquery.fec.gov/cgi-bin/fecimg/?119725...
#
#                                    line_number_label
# 0  Contributions From Individuals/Persons Other T...
# 1  Contributions From Individuals/Persons Other T...
# 2  Contributions From Individuals/Persons Other T...
# 3  Contributions From Individuals/Persons Other T...
# 4  Contributions From Individuals/Persons Other T...
#
# [5 rows x 79 columns]

# %%
df_selections = df[[ "committee_name", "contribution_receipt_date",
                    "contribution_receipt_amount", "contributor_employer", 
                   "contributor_occupation"]]

# %%
faux = ["MISSOURI", "BRITISH", "DISTRICT", "CHICAGO", "INTERNATIONAL", "MO", "UNIVERSITY HOSPITAL", "FLORIDA"]

df_selections = df_selections[~df_selections.contributor_employer.str.contains('|'.join(faux))]

# %%
df_selections.committee_name.unique()
#OBAMA Victory Fund, OBAMA for President, OBAMA Action Fund are funds with OBAMA in name
# Out:
# array(["EMILY'S LIST", 'FRIENDS OF SENATOR CARL LEVIN',
#        'OBAMA FOR AMERICA', 'AL FRANKEN FOR SENATE', 'ACTBLUE',
#        'NEW JERSEY REPUBLICAN STATE COMMITTEE',
#        'HILLARY CLINTON FOR PRESIDENT', 'OBAMA VICTORY FUND',
#        'BILL FOSTER FOR CONGRESS COMMITTEE', 'NADER FOR PRESIDENT 2008',
#        'JOE GARCIA FOR CONGRESS', 'JOHN EDWARDS FOR PRESIDENT',
#        'DEMOCRATIC SENATORIAL CAMPAIGN COMMITTEE', 'RANGEL FOR CONGRESS',
#        'ALASKANS FOR BEGICH', 'SHULMAN FOR CONGRESS',
#        'DARCY BURNER FOR CONGRESS', 'RICK NORIEGA FOR TEXAS',
#        'MCCAIN-PALIN VICTORY 2008', 'MOVEON.ORG POLITICAL ACTION',
#        'COMMITTEE TO ELECT CHRIS MURPHY', 'MARTIN FOR SENATE INC',
#        "1199 SERVICE EMPLOYEES INT'L UNION FEDERAL POLITICAL ACTION FUND",
#        'COMMITTEE TO ELECT ALAN GRAYSON',
#        'DNC SERVICES CORPORATION/DEMOCRATIC NATIONAL COMMITTEE',
#        'JUDY FEDER FOR CONGRESS', 'JSTREETPAC', 'MUSGROVE FOR U S SENATE',
#        'TOM ALLEN FOR SENATE', 'KISSELL FOR CONGRESS',
#        'REPUBLICAN NATIONAL COMMITTEE', 'TRAUNER FOR CONGRESS',
#        'JEFF MERKLEY FOR OREGON', 'ROBERT WEXLER FOR CONGRESS COMMITTEE',
#        'AMERICAN COLLEGE OF SURGEONS PROFESSIONAL ASSOCIATION PAC',
#        'FRIENDS OF SESSIONS SENATE COMMITTEE INC',
#        'JOHN MCCAIN 2008 INC.', 'FRIENDS OF HILLARY',
#        'FRIENDS OF GLENN NYE', 'WULSIN FOR CONGRESS',
#        'JIM HIMES FOR CONGRESS', 'DEMOCRACY FOR AMERICA',
#        'TUKE FOR TENNESSEE', 'FRED THOMPSON POLITICAL ACTION COMMITTEE',
#        'FALLON FOR CONGRESS COMMITTEE', 'JOHN SARBANES FOR CONGRESS',
#        'FRIENDS OF BRUCE LUNSFORD', 'COLORADO DEMOCRATIC PARTY',
#        'KRYZAN FOR CONGRESS', 'JOHN HALL FOR CONGRESS',
#        'DONNA EDWARDS FOR CONGRESS', 'LAROCCO FOR SENATE',
#        'FRIENDS OF CAROLYN MCCARTHY', 'VOTE TODAY OHIO',
#        'MARTIN HEINRICH FOR CONGRESS', 'SAUL FOR CONGRESS INC',
#        'ANDREW RICE FOR US SENATE INC', 'COLLINS FOR SENATOR',
#        'GENERATION BLUE', 'HAGAN SENATE COMMITTEE INC',
#        'MARKEY FOR CONGRESS', 'FRIENDS OF DAN MAFFEI',
#        'PERRIELLO FOR CONGRESS', 'HOWARD SHANKER FOR CONGRESS',
#        'LAUTENBERG FOR SENATE', 'BENNETT 2008', 'NEBRASKANS FOR KLEEB',
#        'BLUE AMERICA PAC', '21ST CENTURY DEMOCRATS',
#        'RANGEL VICTORY FUND', 'MCCAIN VICTORY 2008', 'MASSA FOR CONGRESS',
#        'DEMOCRACY ENGINE', 'BOB LORD FOR CONGRESS',
#        'FRIENDS OF TRACEY BROOKS', 'REGINA D THOMAS FOR CONGRESS',
#        'MICHIGAN DEMOCRATIC STATE CENTRAL COMMITEE',
#        'ANDY HARRIS FOR CONGRESS', 'MCCAIN-PALIN COMPLIANCE FUND INC.',
#        'CASTLE CAMPAIGN FUND', 'HIGGINS FOR CONGRESS',
#        'RE-ELECT CONGRESSMAN KUCINICH COMMITTEE',
#        'RAUL MARTINEZ FOR CONGRESS', 'ROMNEY FOR PRESIDENT INC.',
#        'JEANNE SHAHEEN FOR SENATE', 'MARK PRYOR FOR US SENATE',
#        'KAPTUR FOR CONGRESS', 'MADIA FOR U S CONGRESS',
#        'BROWN FOR CONGRESS', 'SOLUTIONS AMERICA PAC',
#        'AGA TRADE ASSOCIATION INC PAC', 'ANDREWS FOR SENATE',
#        'HATFIELD FOR CONGRESS', 'SERRANO FOR CONGRESS',
#        'FRIENDS OF STEPHEN HARRISON', 'CHILDERS FOR CONGRESS',
#        'BORN FIGHTING PAC', 'ALASKA DEMOCRATIC PARTY',
#        'PENNSYLVANIA DEMOCRATIC PARTY', 'HALVORSON FOR CONGRESS',
#        'FRIENDS OF BARBARA BOXER', 'PROGRESSIVE PATRIOTS FUND',
#        'CITIZENS FOR HARKIN', 'HUCKABEE FOR PRESIDENT, INC.',
#        'PINGREE FOR CONGRESS',
#        'COMMITTEE TO ELECT DIANE BENSON FOR CONGRESS; THE',
#        'LANCE FOR CONGRESS', 'AMERICAN NURSES ASSOCIATION PAC',
#        'LAWSON FOR CONGRESS', 'GREEN MOUNTAIN PAC',
#        'FRIENDS OF MARK WARNER', 'SEGALL FOR CONGRESS',
#        'MCCAIN VICTORY COMMITTEE',
#        'NORTH CAROLINA DEMOCRATIC PARTY - FEDERAL',
#        'ROS-LEHTINEN FOR CONGRESS',
#        'AMERICAN ACADEMY OF DERMATOLOGY ASSOCIATION POLITICAL ACTION COMMITTEE',
#        'TADDEO FOR CONGRESS', 'FRIENDS OF GORDON SMITH',
#        'BARNEY FRANK FOR CONGRESS COMMITTEE',
#        'DEMOCRATIC CONGRESSIONAL CAMPAIGN COMMITTEE',
#        'ASSOCIATION FOR THE ADVANCEMENT OF PSYCHOLOGY INC PSYCHOLOGISTS FOR LEG ACTION NOW (PLAN)',
#        'MISSOURI DEMOCRATIC STATE COMMITTEE',
#        'DEMOCRATIC EXECUTIVE COMMITTEE OF FLORIDA',
#        'MONTANA DEMOCRATIC PARTY', 'FRIENDS OF DICK DURBIN COMMITTEE',
#        'NORTH DAKOTA DEMOCRATIC-NONPARTISAN LEAGUE PARTY',
#        'OHIO DEMOCRATIC PARTY', 'DEMOCRATIC PARTY OF WISCONSIN',
#        'NATIONAL REPUBLICAN SENATORIAL COMMITTEE', 'BAKER FOR CONGRESS',
#        'BILL MCCAMLEY FOR CONGRESS',
#        'AMERICAN ACADEMY OF NEUROLOGY PROFESSIONAL ASSOCIATION BRAIN PAC; THE',
#        'JILL DERBY FOR CONGRESS', 'TINKLENBERG FOR CONGRESS',
#        'BACHMANN FOR CONGRESS', 'FRIENDS FOR JIM MCDERMOTT'], dtype=object)

# %%
df_OBAMA = df_selections[df_selections["committee_name"].str.contains("OBAMA")]

df_OBAMA.reset_index()

df_MCCAIN = df_selections[df_selections["committee_name"].str.contains("MCCAIN")]

df_MCCAIN.reset_index()
# Out:
#     index                     committee_name contribution_receipt_date  \
# 22                    SCIENTIST
# 23                    SCIENTIST
# 24            ADJUNCT PROFESSOR
# 25               MEDICAL DOCTOR
# 26                   PROGRAMMER
# 27                    PROFESSOR
# 28                    PHYSICIAN
# 29                      STUDENT
# 30                         M.D.
# 31                NEURO SURGEON
# 32                         M.D.
# 33            RESEARCH DIRECTOR
# 34      DIR. INTERNAL AUDIT -IT
# 35                    PROFESSOR
# 36                NEURO SURGEON
# 37                    PROFESSOR
# 38                    PROFESSOR
# 39                    PROFESSOR
# 40                     RESEARCH
# 41                     RESEARCH
# 42                LAW PROFESSOR
# 43                    PHYSICIAN
# 44                    PHYSICIAN
# 45               MEDICAL DOCTOR
# 46                     ACADEMIC

# %%
df_OBAMA = df_OBAMA.groupby(["contribution_receipt_date"], as_index=False).sum()

df_MCCAIN = df_MCCAIN.groupby(["contribution_receipt_date"], as_index=False).sum()

# %%
from datetime import datetime, timedelta
t = np.arange(datetime(2007,2,10), datetime(2008,11,5), timedelta(days=30)).astype(datetime)
# y = [0, 2000, 4000, 6000, 8000, 10000, 12000, 14000]

ax1 = df_OBAMA.plot(x="contribution_receipt_date", y="contribution_receipt_amount",
             figsize=(14, 6))
ax1.set_xticks(t)
ax1.set_ylim([0, 20000])
ax1.set_title("Contributions to Committees w/ OBAMA in their name since announcement of 2020 OBAMA Candidacy")


ax2 = df_MCCAIN.plot(x="contribution_receipt_date", y="contribution_receipt_amount",
                   figsize=(14,6),
                   color="red")
ax2.set_xticks(t)
ax2.set_ylim([0, 20000])
ax2.set_title("Contributions to Committees w/ MCCAIN in their name since announcement of 2020 OBAMA Candidacy")
# Out:
# Text(0.5, 1.0, 'Contributions to Committees w/ MCCAIN in their name since announcement of 2020 OBAMA Candidacy')

# %%
df_committees = df_selections.groupby(["committee_name"], as_index=False).sum()
df_committees.sort_values(by="contribution_receipt_amount", ascending=False, inplace=True)
df_committees.reset_index(inplace=True)

df_committees.head()
# Out:
#    index                                     committee_name  \
# 0    152                                  OBAMA FOR AMERICA
# 1    153                                 OBAMA VICTORY FUND
# 2     59  DNC SERVICES CORPORATION/DEMOCRATIC NATIONAL C...
# 3     92                      HILLARY CLINTON FOR PRESIDENT
# 4    167                      REPUBLICAN NATIONAL COMMITTEE
#
#    contribution_receipt_amount
# 0                    570986.85
# 1                    230352.69
# 2                    175978.41
# 3                    105792.75
# 4                     48285.00

# %%
ax3 = df_committees.head(15).plot(kind="barh",
                        x = "committee_name",
                        y = "contribution_receipt_amount",
                                 figsize=(10,6))
ax3.invert_yaxis()

# %%
occupations = df_selections["contributor_occupation"].value_counts()
occupations
# Out:
# PROFESSOR                          1264
# GRADUATE STUDENT                    659
# PHYSICIAN                           543
# RESEARCHER                          178
# SCIENTIST                           165
#                                    ...
# EPIDEMIOLOGIST                        1
# DEPUTY CONTROLLER                     1
# RETIRED PROFESSOR OF PEDIATRICS       1
# DIR. INTERNAL AUDIT -IT               1
# WEB DEVELOPER                         1
# Name: contributor_occupation, Length: 494, dtype: int64

# %%
ax4 = occupations.head(15).plot(kind="barh",
                               figsize=(10,6))
ax4.invert_yaxis()
